# %% [markdown]
# <a href="https://colab.research.google.com/github/pinkyessev2611-Ary/Inteligencia-Artificial/blob/main/NOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# Entradas para la neurona (solo 1entrada por fila)
X = np.array([
    [0],
    [1]
])
# Salidas
Y = np.array([1, 0])
# Pesos para las entradas
W = [-1]
# Umbral para la función de activación
umbral = 0

# %%
class McCullochPitts:
    def __init__(self, weights, umbral):
        """
            Constructor de la neurona MCP.
            Guarda las variables
            weights -> vector de pesos iniciales
            umbral -> umbral para usar en la funcion de activación
        """
        self.weights = weights
        self.umbral = umbral

    def predict(self, X):
        """
            Calcula la salida de la neurona para cada fila de entradas X.
        """
        # Lista donde se guardarán las salidas
        predictions = []
        # Recorremos cada fila de entradas
        for i in range(X.shape[0]):
            # Calculamos la suma ponderada: w1*x1 + w2*x2
            weighted_sum = np.dot(self.weights, X[i])
            # Mostramos en consola la entrada y la suma ponderada
            print(f"Input: {X[i]}, Weighted Sum: {weighted_sum}")
            # Comparación con el umbral determinar si la neurona se activa o no
            if weighted_sum >= self.umbral:
                predictions.append(1)
            else:
                predictions.append(0)
        return predictions

# %%
# Instanciamos la clase McCullochPitts
mcp = McCullochPitts(W, umbral)
# Calculamos las predicciones
predictions = mcp.predict(X)
# Mostramos el resultado final
print("Predictions:", predictions)
# Out:
# Input: [0], Weighted Sum: 0
# Input: [1], Weighted Sum: -1
# Predictions: [1, 0]

# %% [markdown]
# Neurona McCulloch-Pitts NOT
# El modelo compuerta NOT se invierte con el valor de entrada usando el peso negativo y el umbral de 0.
#
# entrada y peso: recibe una sola entrada y se asigna el peso de -1
#
# en la suma ponderada: Se multiplica la entrada por su peso.
#
# El umbral de activacion (0 = 0)
#
# La entrada 0: la suma de 0 alcanza el umbral > 0 y la nurona le respone a 1.
#
# en la entrada 1:  la suma de -1 no alcanza el umbral < 0 y la neurona responde 0.
#
# el peso negativo se invierte en la entrada 0, se convierte en un 1 y un 1 se convierte en 0 cumpliendo la tabla de verdad NOT.
